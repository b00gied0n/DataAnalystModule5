# %% [markdown]
# ## Multiple Linear Regression

# %% [markdown]
# #### The Goal
# To apply linear regression in Python to determine the predicted demand for the London cycle hire scheme for the next 12-month period.

# %% [markdown]
# #### About the datasets
#
#
# There are three datasets in total. These are:
#
# bike_data_2021_part1.xlsx
# bike_data_2021_part2.xlsx
# Bike_data_new.xlsx
#
# The datasets track specific weather conditions that may affect the dependent variable. There are 14 variables included in the datasets; these are listed below. The bikecount variable is the dependent variable.
#
# The three datasets answer the business question:
# ‘What is the predicted demand for the London cycle hire scheme for the next 12-month period?’
#
# Variables
#
#     1.	timestamp – a unique date and time stamp
#     2.	year - categorical field showing the year 2021
#     3.	season - categorical field showing meteorological seasons:
#             •	Spring (March-May)
#             •	Summer (June-August)
#             •	Autumn (September-November)
#             •	Winter (December-February)
#     4.	month - categorical field showing the months: January-December
#             •	1 = January
#             •	2 = February
#             •	3 = March
#             •	4 = April
#             •	5 = May
#             •	6 = June
#             •	7 = July
#             •	8 = August
#             •	9 = September
#             •	10 = October
#             •	11 = November
#             •	12 = December
#     5.	day – categorical field showing the day of the week: Monday-Sunday
#             •	1 = Monday
#             •	2 = Tuesday
#             •	3 = Wednesday
#             •	4 = Thursday
#             •	5 = Friday
#             •	6 = Saturday
#             •	7 = Sunday
#     6.	hour - categorical field showing the hours from 0-23
#     7.	isholiday - category field that shows whether or not the day is a public holiday
#             •	1 = holiday
#             •	0 = non holiday
#     8.	isweekend - categorical field that shows whether the day is a weekend or weekday
#             •	1 = weekend
#             •	0 = weekday
#     9.	weathercode - categorical field showing the days weather status
#             •	1 = mostly clear but have some areas with patches of fog/haze
#             •	2 = scattered clouds or few clouds
#             •	3 = Broken clouds
#             •	4 = Cloudy
#             •	7 = Rain/ light Rain shower
#             •	10 = Rain with thunderstorm
#             •	26 = Snowfall
#             •	94 = Freezing Fog
#     10.	t1 – numerical field showing the real temperature in degrees Celsius
#     11.	t2 – numerical field showing the "feels like" temperature in degrees Celsius
#     12.	humidity - numerical field showing the humidity in percentage
#     13.	wind - numerical field showing the wind speed in km/h
#     14.	bikecount - numerical field showing the the count of new bike shares

# %% [markdown]
# #### Process map
# Below illustrates the process used during this lab.
#
#
#
# TASK 2 - INVENTORY ANALYSIS
#
# SECTION A - IMPORT & COMBINE DATA
#
#     A.1 Access to Jupyter Notebook (COMPLETED)
#     A.2 Set default folder (COMPLETED)
#     A.3 Open file "Module 5 Fusion Day.ipynb" (COMPLETED)
#     A.4 Install Python Libraries
#     A.5 Import data
#     A.6 Combine datasets
#
# SECTION B - DATA PREPARATION
#
#     B.1 Data Quality Checks
#         B.1.1 View sample of data
#         B.1.2 Shape of data
#         B.1.3 Duplicate rows
#         B.1.4 Missing data
#     B.2 Data Cleansing
#         B.2.1 Convert variables to appropriate data types
#         B.2.2 Remove duplicate rows
#         B.2.3 Interpolate using median
#
# SECTION C - EXPLANATORY DATA ANALYSIS & VISUALISATION
#
#     C.1 Aggregation - Calculate total & avg bike shares
#     C.2 Distribution - Calculate total & avg bike shares by:
#         C.2.1 Season
#         C.2.2 Month
#         C.2.3 Day of week
#         C.2.4 Day of week for most popular month
#         C.2.5 Calculate All descriptive stats (for numerical variables only)
#         C.2.6 Is bike shares distribution normal or skewed?
#     C.3 Correlation
#         C.3.1 Correlation Matrix
#         C.3.2 Note correlated variables
#     C.4 Visualisations
#         C.4.1 Create a jointplot
#         C.4.2 Create a lineplot
#         C.4.3 Create a pairgrid
#         C.4.4 Note findings
#
# SECTION D - PREDICTIVE MODELLING (REGRESSION)
#
#     D.1 Pre-processing
#         D.1.1 Remove variables "timestamp" & "year"
#         D.1.2 Encode categorical data
#     D.2 Train/Test Split (70%/30%)
#         D.2.1 Split df dataset to X & Y datasets
# 		D.2.2 Perform 70:30 random split (use "random_state=1")
#     D.3 Build Linear Regression
# 		D.3.1 Save the regression function "LinearRegression()" into a container called "model"
# 		D.3.2 Fit the regression into the training data
#     D.4 Evaluate (training dataset)
#         D.4.1 Identify regression intercept
# 			D.4.1a Reformat intercept into a dataframe
#         D.4.2 Identify regression coefficients
# 			D.4.2a Reformat coefficients into a dataframe
#     D.5 Run Model on Testing Dataset
#     D.6 Calculate R-squared and RMSE from D.5
#
# SECTION E - INTERPRET RESULTS
#
#
# TASK 3 - MODEL PREDICTIONS
#
#     1. IMPORT NEW DATA 'bike_data_new.xlsx'
#     2. DATA QUALITY CHECKS
#     3. DATA CLEANSING
#         3.1 Remove duplicates
#         3.2 Remove missing data
#         3.3 Make a copy of dataset
#         3.4 Convert variables to appropriate data types
#     4. PRE-PROCESSING
#         4.1 Remove variables "timestamp" & "year"
#         4.2 Encode categorical data
#     5. PREDICTION
#         5.1 Use model to predict bike shares
#         5.2 Combine predicted bikeshares from 5.1 with the new data ('bike_data_new.xlsx')
# 			5.2.1 Reformat predictions into a dataframe called 'dfr'
# 			5.2.2 Create a new dataframe that joins 'dfr' to the 'dfp_copy'
#     6. SAVE PREDICTIONS (into csv)

# %% [markdown]
# ### SECTION A - IMPORT & COMBINE DATA

# %%
#   A.1 Access to Jupyter Notebook (COMPLETED)
#   A.2 Set default folder (COMPLETED)
#   A.3 Open file "Module 5 Fusion Day.ipynb" (COMPLETED)#### A.5 IMPORT DATA

# %% [markdown]
# #### A.4 Install Python Libraries

# %%
# RUN/EXCEUTE THE ENTIRE CELL

# INSTALL LIBRARIES
#!pip install pandas
#!pip install numpy
#!pip install scikit-learn
#!pip install scipy
#!pip install seaborn
#!pip install matplotlib#### Import Python Libraries


# IMPORT LIBRARIES
# These libraries are commonly used in data science
import numpy as np
import pandas as pd
import math
import scipy


# Import different modules from the sklearn library to build and evaluate the linear regression model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


# Import matplotlib and seaborn libraries for data visualisation 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


# Switch off unnecessary warning messages 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### A.5 IMPORT DATA

# %%
# Read data from an "bike_data_2021_part1.xlsx" file and save that data into a dataframe called "df1"

# Answer:
df1 = pd.read_excel("bike_data_2021_part1.xlsx")
df1
# Out:
#                timestamp  year  season  month  day  hour  isholiday  isweekend
# 0    2021-01-01 00:00:00  2021  Winter      1    5     0          1          0
# 1    2021-01-01 00:00:00  2021  Winter      1    5     0          1          0
# 2    2021-01-01 00:00:00  2021  Winter      1    5     0          1          0
# 3    2021-01-01 01:00:00  2021  Winter      1    5     1          1          0
# 4    2021-01-01 02:00:00  2021  Winter      1    5     2          1          0
# ...                  ...   ...     ...    ...  ...   ...        ...        ...
# 8672 2021-12-31 19:00:00  2021  Winter     12    5    19          0          0
# 8673 2021-12-31 20:00:00  2021  Winter     12    5    20          0          0
# 8674 2021-12-31 21:00:00  2021  Winter     12    5    21          0          0
# 8675 2021-12-31 22:00:00  2021  Winter     12    5    22          0          0
# 8676 2021-12-31 23:00:00  2021  Winter     12    5    23          0          0
#
# [8677 rows x 8 columns]

# %%
# Read data from an "bike_data_2021_part2.xlsx" file and save that data into a dataframe called "df2"

# Answer:
df2 = pd.read_excel("bike_data_2021_part2.xlsx")
df2
# Out:
#                timestamp  weathercode   t1   t2  humidity  windspeed  \
# 0    2021-01-01 00:00:00            1  6.0  3.5      81.0       13.0
# 1    2021-01-01 00:00:00            1  6.0  3.5      81.0       13.0
# 2    2021-01-01 00:00:00            1  6.0  3.5      81.0       13.0
# 3    2021-01-01 01:00:00            1  5.5  3.0      84.0       11.0
# 4    2021-01-01 02:00:00            1  5.0  2.5      84.0       10.0
# ...                  ...          ...  ...  ...       ...        ...
# 8672 2021-12-31 19:00:00            4  9.0  6.0      82.0       17.0
# 8673 2021-12-31 20:00:00            4  8.5  6.5      84.5       13.0
# 8674 2021-12-31 21:00:00            4  8.0  6.0      87.0       12.0
# 8675 2021-12-31 22:00:00            4  8.0  6.0      90.0       12.0
# 8676 2021-12-31 23:00:00            4  8.0  5.0      87.0       18.5
#
#       bikecount
# 0           786
# 1           786
# 2           786
# 3           660
# 4           387
# ...         ...
# 8672        493
# 8673        465
# 8674        474
# 8675        587
# 8676        697
#
# [8677 rows x 7 columns]

# %% [markdown]
# #### A.6 COMBINE DATASETS

# %%
# Left Join data from df1 and df2, and save that data into a dataframe called "df" - use variable "timestamp" as the join key

# Answer:
df = pd.merge(df1, df2, how="left", left_on="timestamp", right_on="timestamp")
df
# Out:
#                timestamp  year  season  month  day  hour  isholiday  \
# 0    2021-01-01 00:00:00  2021  Winter      1    5     0          1
# 1    2021-01-01 00:00:00  2021  Winter      1    5     0          1
# 2    2021-01-01 00:00:00  2021  Winter      1    5     0          1
# 3    2021-01-01 00:00:00  2021  Winter      1    5     0          1
# 4    2021-01-01 00:00:00  2021  Winter      1    5     0          1
# ...                  ...   ...     ...    ...  ...   ...        ...
# 8678 2021-12-31 19:00:00  2021  Winter     12    5    19          0
# 8679 2021-12-31 20:00:00  2021  Winter     12    5    20          0
# 8680 2021-12-31 21:00:00  2021  Winter     12    5    21          0
# 8681 2021-12-31 22:00:00  2021  Winter     12    5    22          0
# 8682 2021-12-31 23:00:00  2021  Winter     12    5    23          0
#
#       isweekend  weathercode   t1   t2  humidity  windspeed  bikecount
# 0             0            1  6.0  3.5      81.0       13.0        786
# 1             0            1  6.0  3.5      81.0       13.0        786
# 2             0            1  6.0  3.5      81.0       13.0        786
# 3             0            1  6.0  3.5      81.0       13.0        786
# 4             0            1  6.0  3.5      81.0       13.0        786
# ...         ...          ...  ...  ...       ...        ...        ...
# 8678          0            4  9.0  6.0      82.0       17.0        493
# 8679          0            4  8.5  6.5      84.5       13.0        465
# 8680          0            4  8.0  6.0      87.0       12.0        474
# 8681          0            4  8.0  6.0      90.0       12.0        587
# 8682          0            4  8.0  5.0      87.0       18.5        697
#
# [8683 rows x 14 columns]

# %% [markdown]
# ### SECTION B - DATA PREPARATION

# %% [markdown]
# #### B.1 Data Quality Checks
#
#         B.1.1 View sample of data
#         B.1.2 Shape of data
#         B.1.3 Duplicate rows
#         B.1.4 Missing data

# %%
#B.1.1 VIEW SAMPLE OF DATA

# Question 1: Use the right function to view top 5 records

#Answer:
df.head()


# Question 2: View last 5 records

#Answer:
df.tail()


# Question 3: View top 3 records

#Answer:
df.head(n=3)


# Question 4: View last 3 records

#Answer:
df.tail(n=3)
# Out:
#                timestamp  year  season  month  day  hour  isholiday  \
# 8680 2021-12-31 21:00:00  2021  Winter     12    5    21          0
# 8681 2021-12-31 22:00:00  2021  Winter     12    5    22          0
# 8682 2021-12-31 23:00:00  2021  Winter     12    5    23          0
#
#       isweekend  weathercode   t1   t2  humidity  windspeed  bikecount
# 8680          0            4  8.0  6.0      87.0       12.0        474
# 8681          0            4  8.0  6.0      90.0       12.0        587
# 8682          0            4  8.0  5.0      87.0       18.5        697

# %%
#B.1.2 SHAPE OF DATA

# What function can we use to extract the structure (# columns and # of rows) of the dataframe 'df'?

#Answer:
df.shape
# Out:
# (8683, 14)

# %%
#B.1.3 DUPLICATE ROWS

# Use a function to identify how many duplicate records there are in the 'df' dataset

#Answer:
df.duplicated().sum()

# Note: See below to show duplicated records
#df[df.duplicated()]
# Out:
# 8

# %%
#B.1.4 MISSING DATA

#Use the right function on 'df' that will allow us to identify the number of missing data?

# This method prints out information about a dataFrame including the index, dtype, columns, non-null values and memory usage
# This method is also useful for finding out missing values in a dataset

#Answer:
df.info()


# An alternative to identifying missing data 
#df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8683 entries, 0 to 8682
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    8683 non-null   datetime64[ns]
#  1   year         8683 non-null   int64
#  2   season       8683 non-null   object
#  3   month        8683 non-null   int64
#  4   day          8683 non-null   int64
#  5   hour         8683 non-null   int64
#  6   isholiday    8683 non-null   int64
#  7   isweekend    8683 non-null   int64
#  8   weathercode  8683 non-null   int64
#  9   t1           8682 non-null   float64
#  10  t2           8683 non-null   float64
#  11  humidity     8683 non-null   float64
#  12  windspeed    8683 non-null   float64
#  13  bikecount    8683 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(8), object(1)
# memory usage: 1017.5+ KB

# %% [markdown]
# #### B.2 Data Cleansing
#
#         B.2.1 Convert variables to appropriate data types
#         B.2.2 Remove duplicate rows
#         B.2.3 Interpolate using median

# %%
#Run the script below to convert some appropriate variables using astype() method

df["timestamp"] = df.timestamp.astype("datetime64")
df["year"] = df.year.astype("category")
df["season"] = df.season.astype("category")
df["month"] = df.month.astype("category")
df["day"] = df.day.astype("category")
df["hour"] = df.hour.astype("category")
df["isholiday"] = df.isholiday.astype("category")
df["isweekend"] = df.isweekend.astype("category")
df["weathercode"] = df.weathercode.astype("category")
df["t1"] = df.t1.astype("float64")
df["humidity"] = df.humidity.astype("float64")
df["windspeed"] = df.windspeed.astype("float64")

# %%
# B.2.1 - CONVERT VARIABLES TO APPROPRIATE DATA TYPES


#Question 1: Use the approriate script to convert variable 't2' into float

#Answer
df["t2"] = df.t2.astype("float64")


#Question 2: Use the approriate script to convert variable 'bikecount' into int64

#Answer
df["bikecount"] = df.bikecount.astype("int64")


#Question 3: What function can we use to check if you were successful?

#Answer
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8683 entries, 0 to 8682
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    8683 non-null   datetime64[ns]
#  1   year         8683 non-null   category
#  2   season       8683 non-null   category
#  3   month        8683 non-null   category
#  4   day          8683 non-null   category
#  5   hour         8683 non-null   category
#  6   isholiday    8683 non-null   category
#  7   isweekend    8683 non-null   category
#  8   weathercode  8683 non-null   category
#  9   t1           8682 non-null   float64
#  10  t2           8683 non-null   float64
#  11  humidity     8683 non-null   float64
#  12  windspeed    8683 non-null   float64
#  13  bikecount    8683 non-null   int64
# dtypes: category(8), datetime64[ns](1), float64(4), int64(1)
# memory usage: 545.1 KB

# %%
# B.2.2 - REMOVE DUPLICATE ROWS

# Please remove all the duplicates from the dataset 'df' 

#Answer:
df = df.drop_duplicates()

# %%
# B.2.3 - INTERPOLATE USING MEDIAN

# For variable 't1', use appropriate function to fill in missing values with the median

#Answer:
df.t1 = df.t1.fillna(df.t1.median())



# Alternatively you can use appropriate function to fill in missing values for all columns
# df = df.fillna(df.median())

# %% [markdown]
# ### SECTION C - EXPLANATORY DATA ANALYSIS & VISUALISATION

# %% [markdown]
# #### C.1 Aggregation

# %%
# Calculate total and average bike shares for the year 2021

#Answer:
df.agg({"bikecount": ['sum', 'mean']})


# To change format and suppress exponential notation, run code below and then rerun the answer:
#pd.set_option('display.float_format', '{:,.2f}'.format)
# Out:
#          bikecount
# sum   1.010596e+07
# mean  1.164952e+03

# %% [markdown]
# #### C.2 Distribution
#
# Calculate total and average bike shares for the following:
#
#         C.2.1 Season
#         C.2.2 Month
#         C.2.3 Day of week
#         C.2.4 Day of week for the most popular month
#         C.2.5 Calculate all descriptive stats (for numerical variables only)
#         C.2.6 Is bike shares distribution normal or skewed?

# %%
# C.2.1 - SEASON
# Create a report to showcase the total and average bike shares for each season. 
# And identify the season with the highest average value.

#Answer: Summer
df.groupby(by=["season"]).agg({"bikecount": ['sum','mean']}).dropna()
# Out:
#        bikecount
#              sum         mean
# season
# Autumn   2638184  1229.922611
# Spring   2427307  1107.348084
# Summer   3236719  1480.658280
# Winter   1803751   838.174257

# %%
# C.2.2 - MONTH
# Create a report to showcase the total and daily average bike shares for each month.
# And identify the month with the highest average value.

#Answer:7
df.groupby(by=["month"]).agg({"bikecount": ['sum','mean']}).dropna()
# Out:
#       bikecount
#             sum         mean
# month
# 1        582518   782.954301
# 2        569325   857.417169
# 3        656527   900.585734
# 4        768845  1069.325452
# 5       1001935  1346.686828
# 6        933878  1324.649645
# 7       1165527  1572.910931
# 8       1137314  1536.910811
# 9        998619  1462.106881
# 10       935706  1259.362046
# 11       703859   978.941586
# 12       651908   876.220430

# %%
# C.2.3 - DAY OF WEEK
# Create a report to showcase the total and average bike shares for each day of the week. 
# And identify the day with the highest average value.

#Answer:3
df.groupby(by=["day"]).agg({"bikecount": ['sum','mean']}).dropna()
# Out:
#     bikecount
#           sum         mean
# day
# 1     1561968  1259.651613
# 2     1593049  1276.481571
# 3     1588928  1277.273312
# 4     1445329  1196.464404
# 5     1283056  1023.170654
# 6     1264394  1023.800810
# 7     1369237  1098.906100

# %%
# C.2.4 - DAY OF WEEK FOR MOST POPULAR MONTH
# Create a report to showcase the total and average bike shares each day of week for the month with the highest average value. 
# And identify the day with the highest average value.

#Answer:Day of Week = 1
df[df.month==7].groupby(by=["day"]).agg({"bikecount": ['sum','mean']}).dropna()
# Out:
#     bikecount
#           sum         mean
# day
# 1      158374  1649.729167
# 2      156106  1626.104167
# 3      151596  1612.723404
# 4      172522  1437.683333
# 5      189713  1580.941667
# 6      183803  1544.563025
# 7      153413  1598.052083

# %%
# C.2.5 - CALCULATE ALL DESCRIPTIVE STATS (for numerical variables only)
# Use a function to showcase all the descriptive statics for all numerical variables. 

#Answer:
df.describe()
# Out:
#                 t1           t2     humidity    windspeed    bikecount
# count  8675.000000  8675.000000  8675.000000  8675.000000  8675.000000
# mean     12.400442    11.404015    73.202133    15.187800  1164.952277
# std       5.882398     6.905712    14.226331     7.684986  1107.334534
# min      -1.000000    -5.000000    23.000000     0.000000     9.000000
# 25%       8.000000     5.500000    64.000000     9.000000   253.000000
# 50%      12.000000    12.000000    76.000000    14.000000   863.000000
# 75%      17.000000    17.000000    84.000000    19.500000  1712.000000
# max      33.000000    32.500000   100.000000    56.000000  5422.000000

# %%
# C.2.6 Is bike shares distribution normal or skewed? 

#Answer: Positive Skew

# %% [markdown]
# #### C.3 Correlation

# %%
# C.3.1 - CORRELATION MATRIX

# As part of your exploratory analysis use the right function to calculate the correlation for the numerical variables. 

#Answer:
df.corr()
# Out:
#                  t1        t2  humidity  windspeed  bikecount
# t1         1.000000  0.988868 -0.443998   0.131653   0.390171
# t2         0.988868  1.000000 -0.401841   0.065662   0.373690
# humidity  -0.443998 -0.401841  1.000000  -0.265175  -0.461417
# windspeed  0.131653  0.065662 -0.265175   1.000000   0.122492
# bikecount  0.390171  0.373690 -0.461417   0.122492   1.000000

# %%
# C.3.2 - Note down which variables are strongly correlated.

#Answer:t1-t2



# below code can be used to remove any columns due to multicollinearity
# df = df.drop(["t1"], axis=1)
# df.info()

# %% [markdown]
# #### C.4 Visualisations
#
#         C.4.1 Create a jointplot
#         C.4.2 Create a lineplot
#         C.4.3 Create a pairgrid
#         C.4.4 Note findings

# %%
# C.4.1 - CREATE A JOINTPLOT

# Use seaborn to create a jointplot that shows the datapoints between the variables 'bikecount' and 't1' 
# Please label the axis accordingly

#Answer:
sns.jointplot(data=df, x="bikecount", y="t1")
plt.xlabel("Bike Count")
plt.ylabel("Temperature")
plt.show()


#CHALLENGE: Add hue to the script above to break down the data by the variable 'season':

#Answer:
sns.jointplot(data=df, x="bikecount", y="t1", hue="season")
plt.xlabel("Bike Count")
plt.ylabel("Temperature")
plt.show()

# %%
# C.4.2 - CREATE A LINEPLOT

# Use seaborn to create a line plot that shows 'month' in the x-axis and 'bikecount' in the y axis 
# Please label the axis accordingly

#Answer:
sns.lineplot(data=df, x="month", y="bikecount")
plt.title("Bike share analysis")
plt.xlabel("Month")
plt.ylabel("Bike Count")
plt.show()


#CHALLENGE: Add hue to the script above to break down the data by the variable 'isweekend':

#Answer:
sns.lineplot(data=df, x="month", y="bikecount", hue="isweekend")
plt.title("Bike share analysis")
plt.xlabel("Month")
plt.ylabel("Bike Count")
plt.show()

# %%
# C.4.3 - CREATE A PAIRGRID
# Use seaborn to plot a PairGrid with histograms and scatterplots for variables ["t1","t2","humidity","windspeed","bikecount"]
# Please label the axis accordingly

#Answer:
g = sns.PairGrid(data=df, vars=["t1","t2","humidity","windspeed","bikecount"])
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()


#CHALLENGE: Add hue to the script above to break down the data by the variable 'season':

#Answer:
g = sns.PairGrid(data=df, hue="season", vars=["t1","t2","humidity","windspeed","bikecount"])
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()

# %%
#C.4.4 - NOTE FINDINGS BELOW

#Answer: There is a strong correlation between bikeshares and temperature or season.

# %% [markdown]
# ### SECTION D - PREDICTIVE MODELLING (REGRESSION)

# %% [markdown]
# #### D.1 PRE-PROCESSING
#
#     D.1.1	Remove “timestamp” and “year” variables from the dataset
#     D.1.2	Encode categorical data

# %%
# D.1.1 - REMOVE "TIMESTAMP" & "YEAR" VARIABLES

# Use the right function to drop "timestamp" and "year" variables

#Answer:
df = df.drop(["timestamp"], axis=1)
df = df.drop(["year"], axis=1)
df
# Out:
#       season month day hour isholiday isweekend weathercode   t1   t2  \
# 0     Winter     1   5    0         1         0           1  6.0  3.5
# 9     Winter     1   5    1         1         0           1  5.5  3.0
# 10    Winter     1   5    2         1         0           1  5.0  2.5
# 11    Winter     1   5    3         1         0           1  5.0  4.5
# 12    Winter     1   5    4         1         0           1  5.0  4.0
# ...      ...   ...  ..  ...       ...       ...         ...  ...  ...
# 8678  Winter    12   5   19         0         0           4  9.0  6.0
# 8679  Winter    12   5   20         0         0           4  8.5  6.5
# 8680  Winter    12   5   21         0         0           4  8.0  6.0
# 8681  Winter    12   5   22         0         0           4  8.0  6.0
# 8682  Winter    12   5   23         0         0           4  8.0  5.0
#
#       humidity  windspeed  bikecount
# 0         81.0       13.0        786
# 9         84.0       11.0        660
# 10        84.0       10.0        387
# 11        81.0        5.0        294
# 12        76.0        5.5        219
# ...        ...        ...        ...
# 8678      82.0       17.0        493
# 8679      84.5       13.0        465
# 8680      87.0       12.0        474
# 8681      90.0       12.0        587
# 8682      87.0       18.5        697
#
# [8675 rows x 12 columns]

# %%
# D.1.2 - ENCODE CATEGORICAL DATA

# Create dummy variables (one-hot encoding) for the following categorical variables ["season","month","day","hour","isholiday","isweekend","weathercode"]

#Answer:
df = pd.get_dummies(data=df, columns=["season","month","day","hour","isholiday","isweekend","weathercode"], drop_first=True)
df
# Out:
#        t1   t2  humidity  windspeed  bikecount  season_Spring  season_Summer  \
# 0     6.0  3.5      81.0       13.0        786              0              0
# 9     5.5  3.0      84.0       11.0        660              0              0
# 10    5.0  2.5      84.0       10.0        387              0              0
# 11    5.0  4.5      81.0        5.0        294              0              0
# 12    5.0  4.0      76.0        5.5        219              0              0
# ...   ...  ...       ...        ...        ...            ...            ...
# 8678  9.0  6.0      82.0       17.0        493              0              0
# 8679  8.5  6.5      84.5       13.0        465              0              0
# 8680  8.0  6.0      87.0       12.0        474              0              0
# 8681  8.0  6.0      90.0       12.0        587              0              0
# 8682  8.0  5.0      87.0       18.5        697              0              0
#
#       season_Winter  month_2  month_3  ...  hour_22  hour_23  isholiday_1  \
# 0                 1        0        0  ...        0        0            1
# 9                 1        0        0  ...        0        0            1
# 10                1        0        0  ...        0        0            1
# 11                1        0        0  ...        0        0            1
# 12                1        0        0  ...        0        0            1
# ...             ...      ...      ...  ...      ...      ...          ...
# 8678              1        0        0  ...        0        0            0
# 8679              1        0        0  ...        0        0            0
# 8680              1        0        0  ...        0        0            0
# 8681              1        0        0  ...        1        0            0
# 8682              1        0        0  ...        0        1            0
#
#       isweekend_1  weathercode_2  weathercode_3  weathercode_4  weathercode_7  \
# 0               0              0              0              0              0
# 9               0              0              0              0              0
# 10              0              0              0              0              0
# 11              0              0              0              0              0
# 12              0              0              0              0              0
# ...           ...            ...            ...            ...            ...
# 8678            0              0              0              1              0
# 8679            0              0              0              1              0
# 8680            0              0              0              1              0
# 8681            0              0              0              1              0
# 8682            0              0              0              1              0
#
#       weathercode_10  weathercode_26
# 0                  0               0
# 9                  0               0
# 10                 0               0
# 11                 0               0
# 12                 0               0
# ...              ...             ...
# 8678               0               0
# 8679               0               0
# 8680               0               0
# 8681               0               0
# 8682               0               0
#
# [8675 rows x 56 columns]

# %% [markdown]
# #### D.2 TRAIN/TEST SPLIT
#
#     D.2.1 Split df dataset into X & Y datasets
#     D.2.2 Perform 70:30 random split (use "random_state=1")

# %%
#D.2.1 - Split df dataset into X & Y datasets

# Filter the dataset in order to split the 'df' dataset into X & Y datasets

#Answer:
x = df.loc[:, df.columns != "bikecount"]
y = df.loc[:, df.columns == "bikecount"]


#Run checks on data 
#y.head()
#x.head()
#x.shape, y.shape

# %%
#D.2.2 - Perform 70:30 random split (use "random_state=1")

# Split further the 'x' and 'y' datasets data into train and test datasets. 
# Your test size should be 30% (0.3) and please use "random_state=1"
# There should be 4 resulting datasets in the output - x_train, x_test, y_train, y_test

#Answer:
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)


# Run checks on the dimensions to make sure the data was split correctly
#x_train.shape, y_train.shape
#x_test.shape, y_test.shape

# %% [markdown]
# #### D.3 BUILD LINEAR REGRESSION
#     D.3.1 - Save the regression function "LinearRegression()" into a container called 'model'
#     D.3.2 - Fit the regression into the training data

# %%
#D.3.1 - Save the regression function "LinearRegression()" into a container called 'model'

#Answer:
model = LinearRegression()

# %%
#D.3.2 - Fit the regression into the training data 

# use x_train and y_train to fit the regression line

#Answer:
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### D.4 EVALUATE (TRAINING DATASET)
#
#     D.4.1 Identify regression intercept
#         D.4.1a Reformat intercept into a dataframe
#     D.4.2 Identify regression coefficients
#         D.4.2a Reformat coefficients into a dataframe

# %%
#D.4.1 - Identify regression intercept 

# Use the right function to extract intercept of the model

#Answer:
model.intercept_
# Out:
# array([1045.89003507])

# %%
#D.4.1a - Reformat intercept into a dataframe

# The output from D.4.1 is an array format 
# Please reformat the intercept output into a dataframe for a much cleaner view 

#Answer:
pd.DataFrame(np.array(model.intercept_), index=["Intercept"], columns=["Intercept"])
# Out:
#              Intercept
# Intercept  1045.890035

# %%
#D.4.2 - Identify regression coefficients

# Use the right function to extract the coefficients of the model

#Answer:
model.coef_
# Out:
# array([[ 5.55104840e+01, -1.73697456e+01, -1.20814728e+01,
#         -6.30794690e+00, -2.11269268e+01,  2.19591476e+01,
#         -8.93658829e+01, -2.50809797e+01, -8.48039349e+01,
#         -2.33427374e+01,  8.70197456e+01,  3.63002232e+01,
#          1.79237161e+01, -3.22647918e+01, -3.19829186e+01,
#          1.19593103e+02,  9.23478024e-01,  1.06829988e+02,
#          2.96232692e-01, -2.34505655e+01, -5.94842697e+01,
#         -2.15424485e+02, -9.59618487e+01, -4.55019384e+01,
#         -7.13255182e+01, -1.18125454e+02, -1.49188171e+02,
#         -1.54526223e+02, -1.00622751e+02,  2.52143136e+02,
#          1.23313331e+03,  2.62955849e+03,  1.33498923e+03,
#          6.36845658e+02,  6.63395756e+02,  9.10595270e+02,
#          9.65361351e+02,  8.77390184e+02,  9.64001769e+02,
#          1.32965792e+03,  2.34934388e+03,  2.20423088e+03,
#          1.20557152e+03,  6.54953645e+02,  3.60529490e+02,
#          2.64188883e+02,  1.31831286e+02, -2.36481119e+02,
#         -1.41463787e+02,  2.60930257e+01, -4.72691683e+01,
#         -5.00637728e+01, -2.74624792e+02, -5.62312014e+02,
#          2.06768082e+02]])

# %%
#D.4.2a - Reformat coefficients into a dataframe

# The output from D.4.2 is an array 
# Please reformat the coefficients output into a dataframe for a much cleaner view 

#Answer:
pd.DataFrame(np.array(model.coef_).T, index=x.columns, columns=["Coefficients"])
# Out:
#                 Coefficients
# t1                 55.510484
# t2                -17.369746
# humidity          -12.081473
# windspeed          -6.307947
# season_Spring     -21.126927
# season_Summer      21.959148
# season_Winter     -89.365883
# month_2           -25.080980
# month_3           -84.803935
# month_4           -23.342737
# month_5            87.019746
# month_6            36.300223
# month_7            17.923716
# month_8           -32.264792
# month_9           -31.982919
# month_10          119.593103
# month_11            0.923478
# month_12          106.829988
# day_2               0.296233
# day_3             -23.450566
# day_4             -59.484270
# day_5            -215.424485
# day_6             -95.961849
# day_7             -45.501938
# hour_1            -71.325518
# hour_2           -118.125454
# hour_3           -149.188171
# hour_4           -154.526223
# hour_5           -100.622751
# hour_6            252.143136
# hour_7           1233.133307
# hour_8           2629.558492
# hour_9           1334.989229
# hour_10           636.845658
# hour_11           663.395756
# hour_12           910.595270
# hour_13           965.361351
# hour_14           877.390184
# hour_15           964.001769
# hour_16          1329.657922
# hour_17          2349.343881
# hour_18          2204.230885
# hour_19          1205.571516
# hour_20           654.953645
# hour_21           360.529490
# hour_22           264.188883
# hour_23           131.831286
# isholiday_1      -236.481119
# isweekend_1      -141.463787
# weathercode_2      26.093026
# weathercode_3     -47.269168
# weathercode_4     -50.063773
# weathercode_7    -274.624792
# weathercode_10   -562.312014
# weathercode_26    206.768082

# %% [markdown]
# #### D.5 RUN MODEL ON TESTING DATASET

# %%
# Use the right function from regression 'model' to predict the test dataset 'x_test'
# Save the predictions into a container called 'y_pred'

#Answer:
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[-127.68535489],
#        [1637.53392765],
#        [1086.59454895],
#        ...,
#        [3214.97050233],
#        [1349.7209153 ],
#        [2924.1999804 ]])

# %% [markdown]
# #### D.6 CALCULATE R-SQUARED & RMSE

# %%
# Use the rignt scripts to evaluate the overall model performance by showing us the Rsquared and RMSE statistics

#Answer:
print("Root Mean squared error (RMSE):{}".format(math.sqrt(mean_squared_error(y_test, y_pred))))
print("Coefficient of determination (R^2):{}".format(r2_score(y_test, y_pred)))
# Out:
# Root Mean squared error (RMSE):582.344952559939
# Coefficient of determination (R^2):0.7183916206057439

# %% [markdown]
# ### SECTION E - INTERPRET RESULTS

# %%
#EDA Evaluation

#Answer: Demand for bikes seems to be highly dependent on temperature and therefore seasonality. The colder the temperatures, the less demand for bikes. Summer months have the biggest demand for bikes. There is also a strong difference in demand between weekends and weekdays where demand in weekdays is most likele driven by local commuters going to work. In the summer months, there is convergence indicating the spike in tourism during the summer months are driving demand higher irrespective of whether it is in weekdays or weekends. 



#Model Evaluation:

#Answer: R-Squared indicates that 72% of the variability in the dataset can be explained by our model. The model is ok but could be improved.

# %% [markdown]
# # TASK 3 - MODEL PREDICTIONS
# Now that we have a working model, please start preparing the new dataset for the model to predict and output the predictions into csv

# %% [markdown]
# #### 1 - IMPORT NEW DATA 'bike_data_new.xlsx'

# %%
# Import data "bike_data_new.xlsx" and save as a dataframe called 'dfp'

#Answer:
dfp = pd.read_excel("bike_data_new.xlsx")

# %% [markdown]
# #### 2 - DATA QUALITY CHECKS

# %%
# Please use various functions to conduct quality checks on the data


# Answer:

# This method prints out information about a dataFrame including the index, dtype, columns, & missing values
dfp.info()

# IDENTIFY DUPLICATE ROWS
dfp.duplicated().sum()

#MISSING DATA (TOTAL)
dfp.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7490 entries, 0 to 7489
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    7490 non-null   datetime64[ns]
#  1   year         7490 non-null   int64
#  2   season       7490 non-null   object
#  3   month        7490 non-null   int64
#  4   day          7490 non-null   int64
#  5   hour         7490 non-null   int64
#  6   isholiday    7490 non-null   int64
#  7   isweekend    7490 non-null   int64
#  8   weathercode  7490 non-null   int64
#  9   t1           7490 non-null   float64
#  10  t2           7490 non-null   float64
#  11  humidity     7490 non-null   float64
#  12  windspeed    7490 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(7), object(1)
# memory usage: 760.8+ KB
# timestamp      0
# year           0
# season         0
# month          0
# day            0
# hour           0
# isholiday      0
# isweekend      0
# weathercode    0
# t1             0
# t2             0
# humidity       0
# windspeed      0
# dtype: int64

# %% [markdown]
# #### SECTION 3 - DATA CLEANSING

# %%
# 3.1 - REMOVE DUPLICATES

# Remove all the duplicates from 'dfp' 

# Answer:
dfp = dfp.drop_duplicates()

# %%
# 3.2 - REMOVE MISSING DATA

# Remove all the null values from 'dfp'

# Answer:
dfp = dfp.dropna()

# %%
# 3.3 - MAKE A COPY OF DATASET

# Create a copy of the dataset 'dfp' and call it 'dfp_copy'. This will be used during the last stage.

# Answer:
dfp_copy = dfp.copy()

# %%
# 3.4 - CONVERT VARIABLES TO APPROPRIATE DATA TYPES
# Run data conversions below as is:

dfp["timestamp"] = dfp.timestamp.astype("datetime64")
dfp["year"] = dfp.year.astype("category")
dfp["month"] = dfp.month.astype("category")
dfp["day"] = dfp.day.astype("category")
dfp["hour"] = dfp.hour.astype("category")
dfp["isholiday"] = dfp.isholiday.astype("category")
dfp["weathercode"] = dfp.weathercode.astype("category")
dfp["t1"] = dfp.t1.astype("float64")
dfp["t2"] = dfp.t2.astype("float64")
dfp["humidity"] = dfp.humidity.astype("float64")
dfp["windspeed"] = dfp.windspeed.astype("float64")

# %%
#Question 1: Use the approriate script to convert variable 'season' into category

# Answer:
dfp["season"] = dfp.season.astype("category")



#Question 2: Use the approriate script to convert variable 'isweekend' into category

# Answer:
dfp["isweekend"] = dfp.isweekend.astype("category")



#Question 3: What function can we use to check if you were successful?

# Answer:
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7490 entries, 0 to 7489
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    7490 non-null   datetime64[ns]
#  1   year         7490 non-null   category
#  2   season       7490 non-null   category
#  3   month        7490 non-null   category
#  4   day          7490 non-null   category
#  5   hour         7490 non-null   category
#  6   isholiday    7490 non-null   category
#  7   isweekend    7490 non-null   category
#  8   weathercode  7490 non-null   category
#  9   t1           7490 non-null   float64
#  10  t2           7490 non-null   float64
#  11  humidity     7490 non-null   float64
#  12  windspeed    7490 non-null   float64
# dtypes: category(8), datetime64[ns](1), float64(4)
# memory usage: 412.0 KB

# %% [markdown]
# #### SECTION 4 - PRE-PROCESSING

# %%
# 4.1 - REMOVE VARIABLES "TIMESTAMP" & "YEAR"

# drop "timestamp" and "year" columns from 'dfp'

# Answer:
dfp = dfp.drop(["timestamp"], axis=1)
dfp = dfp.drop(["year"], axis=1)
dfp
# Out:
#       season month day hour isholiday isweekend weathercode   t1   t2  \
# 0     Winter     1   6    6         0         1           1  3.0  0.0
# 1     Winter     1   6    7         0         1           1  3.0  0.0
# 2     Winter     1   6    8         0         1           1  3.0  0.0
# 3     Winter     1   6    9         0         1           1  4.5  1.5
# 4     Winter     1   6   10         0         1           1  5.5  2.5
# ...      ...   ...  ..  ...       ...       ...         ...  ...  ...
# 7485  Winter    12   5   18         0         0           4  4.0  2.0
# 7486  Winter    12   5   19         0         0           4  4.0  1.5
# 7487  Winter    12   5   20         0         0           4  4.0  1.5
# 7488  Winter    12   5   21         0         0           4  4.0  1.0
# 7489  Winter    12   5   22         0         0           4  5.0  2.0
#
#       humidity  windspeed
# 0         87.0       10.0
# 1         87.0       12.0
# 2         87.0       12.0
# 3         84.0       14.0
# 4         76.0       17.0
# ...        ...        ...
# 7485     100.0        9.0
# 7486     100.0       11.0
# 7487     100.0       10.0
# 7488     100.0       12.0
# 7489      93.0       12.0
#
# [7490 rows x 11 columns]

# %%
# 4.2 - ENCODE CATEGORICAL DATA

# Create dummy variables (one-hot encoding) from the following categorical variables: ["season","month","day","hour","isholiday","isweekend","weathercode"]
# Please save to 'dfp2'

# Answer:
dfp2 = pd.get_dummies(data=dfp,columns=["season","month","day","hour","isholiday","isweekend","weathercode"], drop_first=True)

#Check variables
#dfp2.info()

# %% [markdown]
# #### SECTION 5 - PREDICTION

# %% [markdown]
# #### 5.1 USE MODEL TO PREDICT BIKE SHARES

# %%
# Use the "model" to predict dfp2 and save results to 'newbikeshares'

# Answer:
newbikeshares = model.predict(dfp2)

# %% [markdown]
# #### 5.2 - COMBINE PREDICTED BIKE SHARE DATA FROM 5.1 WITH THE NEW DATA ('bike_data_new.xlsx')
#     5.2.1 - Reformat predictions into a dataframe called 'dfr'
#     5.2.2 - Create a new dataframe that joins dfr to the 'dfp_copy'

# %%
# 5.2.1 - Reformat predictions into a dataframe called 'dfr' and name the new column "newbikecount"

# Answer:
dfr = pd.DataFrame(newbikeshares, columns=["newbikecount"])
dfr
# Out:
#       newbikecount
# 0        23.605499
# 1       991.979776
# 2      2388.404961
# 3      1174.675330
# 4       592.400440
# ...            ...
# 7485   1924.480406
# 7486    921.890016
# 7487    377.580092
# 7488     79.224917
# 7489    105.595358
#
# [7490 rows x 1 columns]

# %%
# 5.2.2 - Create a new dataframe 'newdf' that joins 'dfr' to the 'dfp_copy' 
#note: dataset 'dfp_copy' was saved in section 3.3 for later reference

# Answer:
newdf = pd.DataFrame.join(dfp_copy,dfr)
newdf
# Out:
#                timestamp  year  season  month  day  hour  isholiday  \
# 0    2022-01-01 06:00:00  2022  Winter      1    6     6          0
# 1    2022-01-01 07:00:00  2022  Winter      1    6     7          0
# 2    2022-01-01 08:00:00  2022  Winter      1    6     8          0
# 3    2022-01-01 09:00:00  2022  Winter      1    6     9          0
# 4    2022-01-01 10:00:00  2022  Winter      1    6    10          0
# ...                  ...   ...     ...    ...  ...   ...        ...
# 7485 2022-12-30 18:00:00  2022  Winter     12    5    18          0
# 7486 2022-12-30 19:00:00  2022  Winter     12    5    19          0
# 7487 2022-12-30 20:00:00  2022  Winter     12    5    20          0
# 7488 2022-12-30 21:00:00  2022  Winter     12    5    21          0
# 7489 2022-12-30 22:00:00  2022  Winter     12    5    22          0
#
#       isweekend  weathercode   t1   t2  humidity  windspeed  newbikecount
# 0             1            1  3.0  0.0      87.0       10.0     23.605499
# 1             1            1  3.0  0.0      87.0       12.0    991.979776
# 2             1            1  3.0  0.0      87.0       12.0   2388.404961
# 3             1            1  4.5  1.5      84.0       14.0   1174.675330
# 4             1            1  5.5  2.5      76.0       17.0    592.400440
# ...         ...          ...  ...  ...       ...        ...           ...
# 7485          0            4  4.0  2.0     100.0        9.0   1924.480406
# 7486          0            4  4.0  1.5     100.0       11.0    921.890016
# 7487          0            4  4.0  1.5     100.0       10.0    377.580092
# 7488          0            4  4.0  1.0     100.0       12.0     79.224917
# 7489          0            4  5.0  2.0      93.0       12.0    105.595358
#
# [7490 rows x 14 columns]

# %% [markdown]
# #### SECTION F - SAVE PREDICTIONS TO CSV

# %%
# Save the above dataframe ("newdf") as a csv file

# Answer:
newdf.to_csv("NewBikeSharePredicted.csv")
